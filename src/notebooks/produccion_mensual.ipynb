# %%
import pandas as pd
import numpy as np
import re

from pathlib import Path

# %%
url_excel = (
    "https://raw.githubusercontent.com/"
    "FabriProm/mercado-asegurador-argentina/"
    "main/data/produccion_mensual/"
    "produccion_mensual.xlsx"
)

print(url_excel)
# Out:
# https://raw.githubusercontent.com/FabriProm/mercado-asegurador-argentina/main/data/produccion_mensual/produccion_mensual.xlsx

# %%
archivo_excel = pd.ExcelFile(url_excel)

hojas_disponibles = archivo_excel.sheet_names

print("Hojas disponibles:")
print(hojas_disponibles)
# Out:
# Hojas disponibles:
# ['Valores Corrientes', 'Valores Constantes']
